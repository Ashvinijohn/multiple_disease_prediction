# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
data = pd.read_csv('oasis_longitudinal.csv')
data.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
data.shape
# Out:
# (373, 15)

# %%
data.isnull().sum()
# Out:
# Subject ID     0
# MRI ID         0
# Group          0
# Visit          0
# MR Delay       0
# M/F            0
# Hand           0
# Age            0
# EDUC           0
# SES           19
# MMSE           2
# CDR            0
# eTIV           0
# nWBV           0
# ASF            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

data['M/F']=le.fit_transform(data['M/F'])
data['Group']=le.fit_transform(data['Group'])
data['Hand']=le.fit_transform(data['Hand'])

# %%
data.head()
# Out:
#   Subject ID         MRI ID  Group  Visit  MR Delay  M/F  Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1      2      1         0    1     0   87    14
# 1  OAS2_0001  OAS2_0001_MR2      2      2       457    1     0   88    14
# 2  OAS2_0002  OAS2_0002_MR1      1      1         0    1     0   75    12
# 3  OAS2_0002  OAS2_0002_MR2      1      2       560    1     0   76    12
# 4  OAS2_0002  OAS2_0002_MR3      1      3      1895    1     0   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df1=data.drop(data[['Subject ID','MRI ID','Visit']],axis=1)
df1.head()
# Out:
#    Group  MR Delay  M/F  Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      2         0    1     0   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1      2       457    1     0   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2      1         0    1     0   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3      1       560    1     0   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4      1      1895    1     0   80    12  NaN  22.0  0.5  1698  0.701  1.034

# %%
df1.isnull().sum()
# Out:
# Group        0
# MR Delay     0
# M/F          0
# Hand         0
# Age          0
# EDUC         0
# SES         19
# MMSE         2
# CDR          0
# eTIV         0
# nWBV         0
# ASF          0
# dtype: int64

# %%
df2=df1.dropna()

# %%
df2.head()
# Out:
#    Group  MR Delay  M/F  Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      2         0    1     0   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1      2       457    1     0   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 5      2         0    0     0   88    18  3.0  28.0  0.0  1215  0.710  1.444
# 6      2       538    0     0   90    18  3.0  27.0  0.0  1200  0.718  1.462
# 7      2         0    1     0   80    12  4.0  28.0  0.0  1689  0.712  1.039

# %%
X = df2.drop(['Group'],axis=1)
Y = df2['Group']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_test[0]
# Out:
# array([-0.90542303,  1.18249951,  0.        ,  0.04750761,  1.85679439,
#        -1.31561925, -1.24476076,  2.02929244,  1.30426947,  0.67644704,
#        -1.2846707 ])

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (354, 11) (283, 11) (71, 11)

# %%
ran_classifier = RandomForestClassifier()

# %%
ran_classifier.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
testing_data_prediction1 = ran_classifier.predict(X_test)

# %%
score1 = metrics.accuracy_score(Y_test,testing_data_prediction1)

# %%
score1
# Out:
# 0.9295774647887324

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

con=confusion_matrix(Y_test,testing_data_prediction1)
con
# Out:
# array([[ 2,  3,  2],
#        [ 0, 26,  0],
#        [ 0,  0, 38]], dtype=int64)

# %%
print(classification_report(Y_test, testing_data_prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.29      0.44         7
#            1       0.90      1.00      0.95        26
#            2       0.95      1.00      0.97        38
#
#     accuracy                           0.93        71
#    macro avg       0.95      0.76      0.79        71
# weighted avg       0.94      0.93      0.91        71

# %%
import joblib
joblib.dump(ran_classifier, 'oasis_model.sav')
# Out:
# ['oasis_model.sav']

# %%
model = joblib.load('oasis_model.sav')

# %%
df2.columns
# Out:
# Index(['Group', 'MR Delay', 'M/F', 'Hand', 'Age', 'EDUC', 'SES', 'MMSE', 'CDR',
#        'eTIV', 'nWBV', 'ASF'],
#       dtype='object')
